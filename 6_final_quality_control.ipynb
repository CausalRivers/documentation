# %%
from tools import plot_current_state_of_graph
import pickle
from IPython.display import HTML
import matplotlib as mpl
import numpy as np
import networkx as nx
import pandas as pd

# %%
cmap = mpl.colormaps['Set1']

# Take colors at regular intervals spanning the colormap.
colors = cmap(np.linspace(0, 1, 6))

# %% [markdown]
# # Here we introduce some displaying tools to check data, graphs and their properties.

# %%
path  = "/home/datasets4/stein/rivers/processed_recreation/"

# %%
# Load necessary data
G = pickle.load(open(path + 'station_G.p', 'rb'))
ba_G = pickle.load(open(path + 'BA_G.p', 'rb'))

# %%
plot_current_state_of_graph(
    ba_G,
    dpi=500,
    autozoom=False,
    lim=(47.2, 50.7),
    limx=(8.8, 14.1),
    node_size=2,
    save=0,
    river_map=1,
    ger_map=1,
    width=1,
    arrowsize=3,
    fs=(10, 10),
    show_edge_origin=True,
    font_size=1,
    ger_path = "product/bavaria_map.shp",
    river_path = "product/river_bavaria_map.shp",
    emphasize=[],
)

# %%
potential_issue = [y for y in [x for x in ba_G.edges.data()] if y[2]["h_distance"] < 0]
print([z for z in [y for y in [x[2]["km"] for x in ba_G.edges.data()] if y] if z < 0 ])
print(list(nx.nodes_with_selfloops(ba_G))),nx.find_cycle(ba_G)
# Out:
# []
# []
# ---------------------------------------------------------------------------
# NetworkXNoCycle                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 potential_issue = [y for y in [x for x in ba_G.edges.data()] if y[2]["h_distance"] < 0]
#       2 print([z for z in [y for y in [x[2]["km"] for x in ba_G.edges.data()] if y] if z < 0 ])
# ----> 3 print(list(nx.nodes_with_selfloops(ba_G))),nx.find_cycle(ba_G)
#
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/networkx/utils/decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:3, in argmap_find_cycle_1(G, source, orientation, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/networkx/algorithms/cycles.py:1023, in find_cycle(G, source, orientation)
#    1021 else:
#    1022     assert len(cycle) == 0
# -> 1023     raise nx.exception.NetworkXNoCycle("No cycle found.")
#    1025 # We now have a list of edges which ends on a cycle.
#    1026 # So we need to remove from the beginning edges that are not relevant.
#    1028 for i, edge in enumerate(cycle):
#
# NetworkXNoCycle: No cycle found.

# %%
plot_current_state_of_graph(
    G,
    dpi=500,
    autozoom=False,
    lim=(50.1, 54.8),
    limx=(9.65, 15.1),
    node_size=1,
    save=0,
    river_map=1,
    ger_map=1,
    width=1,
    arrowsize=3,
    fs=(20, 20),
    show_edge_origin=True,
    font_size=1,
    ger_path = "product/east_german_map.shp",
    river_path = "product/river_east_german_map.shp",
    emphasize=[],
)

# %%
potential_issue = [y for y in [x for x in G.edges.data()] if y[2]["h_distance"] < 0]
print([z for z in [y for y in [x[2]["km"] for x in G.edges.data()] if y] if z < 0 ])
print(list(nx.nodes_with_selfloops(G))),nx.find_cycle(G)
# Out:
# []
# []
# ---------------------------------------------------------------------------
# NetworkXNoCycle                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 potential_issue = [y for y in [x for x in G.edges.data()] if y[2]["h_distance"] < 0]
#       2 print([z for z in [y for y in [x[2]["km"] for x in G.edges.data()] if y] if z < 0 ])
# ----> 3 print(list(nx.nodes_with_selfloops(G))),nx.find_cycle(G)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:3, in argmap_find_cycle_1(G, source, orientation, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/networkx/algorithms/cycles.py:1023, in find_cycle(G, source, orientation)
#    1021 else:
#    1022     assert len(cycle) == 0
# -> 1023     raise nx.exception.NetworkXNoCycle("No cycle found.")
#    1025 # We now have a list of edges which ends on a cycle.
#    1026 # So we need to remove from the beginning edges that are not relevant.
#    1028 for i, edge in enumerate(cycle):
#
# NetworkXNoCycle: No cycle found.

# %%
# FINAL product: 

"BA graph"
"East Germany Graph"
"TS set east germany"
"TS set bavaria"
# Out:
# 'TS set bavaria'

# %% [markdown]
# # FINAL EXPORT

# %%
meta_data = pd.read_csv(path + "meta_joined_final.csv", index_col=0)

# %%
# Save new data file: 
data = pd.read_csv(path + "ts_ds_final.csv", index_col=0)
data.columns = data.columns.astype(int)

# %%
# Meta and data match
np.all(data.columns== meta_data.index)
# Out:
# np.True_

# %%
# Grpahs are exclusive
[x for x in G.nodes if x in ba_G.nodes],[x for x in ba_G.nodes if x in G.nodes]
# Out:
# ([], [])

# %%
data.drop(columns=139, inplace=True)

# %%
meta_data.drop(index=139, inplace=True)

# %%
np.all(meta_data.index == sorted(list(G.nodes) + list(ba_G.nodes))),np.all(data.columns == sorted(list(G.nodes) + list(ba_G.nodes)))
# Out:
# (np.True_, np.True_)

# %%
train = data[list(ba_G.nodes)]
test = data[list(G.nodes)]

# %%
train_meta = meta_data.loc[list(ba_G.nodes)]
test_meta = meta_data.loc[list(G.nodes)]

# %%
pickle.dump(G,open('product/rivers_east_germany.p', 'wb'))
pickle.dump(ba_G,open('product/rivers_bavaria.p', 'wb'))

# %%
train_meta.to_csv("product/rivers_meta_bavaria.csv")
test_meta.to_csv("product/rivers_meta_east_germany.csv")

# %%
train.index.name = "datetime"
test.index.name = "datetime"

# %%
train.to_csv("product/rivers_ts_bavaria.csv" )
test.to_csv("product/rivers_ts_east_germany.csv")
