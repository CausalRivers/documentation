# %%
import pandas as pd

# %%
a = pd.read_csv("product/rivers_meta_bavaria.csv")
b = pd.read_csv("product/rivers_meta_flood.csv")
c = pd.read_csv("product/rivers_meta_east_germany.csv")
a2 = pd.read_csv("/home/stein/project_repos/river_benchmark_package/resources/rivers_meta_bavaria.csv")
b2 = pd.read_csv("/home/stein/project_repos/river_benchmark_package/resources/rivers_meta_flood.csv")
c2 = pd.read_csv("/home/stein/project_repos/river_benchmark_package/resources/rivers_meta_east_germany.csv")

# %%
(a == a2).sum()
# Out:
# ID             494
# R              494
# X                2
# Y              494
# D                0
# H              494
# QD             494
# QH             494
# QX             494
# QY             494
# QR             494
# O              494
# original_id    494
# dtype: int64

# %%
(c - c2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/anaconda3/envs/causal_rivers_construction/lib/python3.13/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ...

# %%
b
# Out:
#       ID                                       R          X          Y  \
# 0     59                                   Bahra  50.832963  13.979672
# 1     77                                   Biela  50.881857  14.046569
# 2    119                      Cunnersdorfer Bach  50.886750  14.108157
# 3    120                                   Dahle  51.386498  13.156530
# 4    152                                Döllnitz  51.314962  13.252934
# 5    153                                Döllnitz  51.241244  13.016951
# 6    174                                    Elbe  51.553683  13.010138
# 7    175                                    Elbe  51.311484  13.293343
# 8    176                                    Elbe  51.054464  13.738837
# 9    177                                    Elbe  50.875763  14.235237
# 10   257                               Gottleuba  50.916254  13.977411
# 11   376                                   Jahna  51.266583  13.254339
# ...

# %%
(a["X"] - a2["X"])
# Out:
# 0     -7.609913e-12
# 1     -5.168270e-08
# 2     -4.699771e-08
# 3     -9.442296e-09
# 4     -9.427893e-09
#            ...
# 489   -2.528267e-07
# 490   -3.471315e-08
# 491   -3.523521e-08
# 492   -8.854428e-10
# 493   -1.836663e-07
# Name: X, Length: 494, dtype: float64
